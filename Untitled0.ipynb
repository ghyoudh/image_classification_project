# %% [markdown]
# <a href="https://colab.research.google.com/github/ghyoudh/image_classification_project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Classification of Natural and Urban Scenes
# This project aims to create and train a robust system for classifying images based on their natural and architectural content. The system will analyze an input image and accurately determine its category from among six main classes: Building, Forest, Glacier, Mountain, Sea, and Street.
#
# This project is a direct and effective application of Fine-Tuning and Transfer Learning techniques within the field of Computer Vision.

# %% [markdown]
# ## Downloading the dataset from github

# %%
# !git clone https://github.com/fafilia/cnn-intel_images.git
# Out:
# Cloning into 'cnn-intel_images'...
# remote: Enumerating objects: 24329, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 24329 (delta 2), reused 5 (delta 2), pack-reused 24323 (from 1)
# Receiving objects: 100% (24329/24329), 351.65 MiB | 36.86 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# Updating files: 100% (24341/24341), done.

# %%
# !wget https://github.com/fafilia/cnn-intel_images/tree/master/seg_train
# !wget https://github.com/fafilia/cnn-intel_images/tree/master/seg_test
# Out:
# --2026-01-08 23:45:50--  https://github.com/fafilia/cnn-intel_images/tree/master/seg_train
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘seg_train’
#
# seg_train               [ <=>                ] 181.25K  1017KB/s    in 0.2s
#
# 2026-01-08 23:45:51 (1017 KB/s) - ‘seg_train’ saved [185605]
#
# --2026-01-08 23:45:52--  https://github.com/fafilia/cnn-intel_images/tree/master/seg_test
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘seg_test’
#
# seg_test                [ <=>                ] 181.24K  1.01MB/s    in 0.2s
#
# 2026-01-08 23:45:52 (1.01 MB/s) - ‘seg_test’ saved [185587]

# %%
# %cd /content/cnn-intel_images

# rename train
# !mv seg_train train

# rename val
# !mv seg_test val

# !ls -F
# Out:
# /content/cnn-intel_images
# assets/		      CNN_IntelImages.ipynb  README.md	train/
# CNN_IntelImages.html  model.h5		     seg_pred/	val/

# %% [markdown]
# ## imports

# %%
# License: BSD
# Author: Sasank Chilamkurthy

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory

cudnn.benchmark = True
plt.ion()   # interactive mode

# %%
import os
import shutil

data_dir = os.getcwd()
print(f"Data Directory set to: {data_dir}")

# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}


# Remove .ipynb_checkpoints folders if they exist
for split in ['train', 'val']:
    checkpoint_path = os.path.join(data_dir, split, '.ipynb_checkpoints')
    if os.path.exists(checkpoint_path):
        shutil.rmtree(checkpoint_path)
        print(f"Removed {checkpoint_path}")

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=2)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

# We want to be able to train our model on an `accelerator <https://pytorch.org/docs/stable/torch.html#accelerators>`__
# such as CUDA, MPS, MTIA, or XPU. If the current accelerator is available, we will use it. Otherwise, we use the CPU.

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using {device} device")
# Out:
# Data Directory set to: /content/cnn-intel_images
# Using cuda:0 device

# %% [markdown]
# ### Visualize a few images

# %%
def imshow(inp, title=None):
    """Display image for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %% [markdown]
# ## Training the model

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                else:
                    model.eval()   # Set model to evaluate mode

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for inputs, labels in dataloaders[phase]:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)
                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'val' and epoch_acc > best_acc:
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)

            print()

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path, weights_only=True))
    return model

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# ## Finetuning for model ResNet

# %%
# Finetuning ResNet
model_ft = models.resnet18(weights='IMAGENET1K_V1')
# without freezing Training complete in 0m 31s Best val Acc: 1.000000 that is an overfitting
# here we add the freezing part
for param in model_ft.parameters():
    param.requires_grad = False # Freeze everything

num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 6.
# Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
model_ft.fc = nn.Linear(num_ftrs, 6)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9) # this is butter
# optimizer_ft = optim.AdamW(model_ft.parameters(), lr=0.001,  weight_decay=1e-3)
# gaived Training complete in 1m 20s Best val Acc: 0.764706

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 90.1MB/s]

# %% [markdown]
# ## Train and evaluate the ResNet finetuning

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.9147 Acc: 0.6697
# val Loss: 0.3924 Acc: 0.8803
#
# Epoch 1/24
# ----------
# train Loss: 0.8492 Acc: 0.7028
# val Loss: 0.4016 Acc: 0.8643
#
# Epoch 2/24
# ----------
# train Loss: 0.8423 Acc: 0.7052
# val Loss: 0.3186 Acc: 0.8920
#
# Epoch 3/24
# ----------
# train Loss: 0.8258 Acc: 0.7165
# val Loss: 0.4658 Acc: 0.8517
#
# Epoch 4/24
# ----------
# train Loss: 0.8300 Acc: 0.7135
# val Loss: 0.4025 Acc: 0.8707
#
# Epoch 5/24
# ----------
# train Loss: 0.8524 Acc: 0.7083
# val Loss: 0.3502 Acc: 0.8843
#
# Epoch 6/24
# ----------
# train Loss: 0.8242 Acc: 0.7135
# val Loss: 0.3372 Acc: 0.8900
#
# Epoch 7/24
# ----------
# train Loss: 0.6975 Acc: 0.7545
# val Loss: 0.3075 Acc: 0.8980
#
# Epoch 8/24
# ----------
# train Loss: 0.6895 Acc: 0.7516
# val Loss: 0.2973 Acc: 0.8993
#
# Epoch 9/24
# ----------
# train Loss: 0.6839 Acc: 0.7532
# val Loss: 0.2970 Acc: 0.8990
#
# Epoch 10/24
# ----------
# train Loss: 0.6629 Acc: 0.7609
# ...

# %%
visualize_model(model_ft)

# %% [markdown]
# ## Finetuning for model EfficientNet

# %%
# Finetuning EfficientNet
model_ft_2 = models.efficientnet_b0(weights='IMAGENET1K_V1')

# Freeze all parameters
for param in model_ft_2.parameters():
    param.requires_grad = False

# Replace the classifier head
# EfficientNet uses 'classifier' instead of 'fc'
num_ftrs_2 = model_ft_2.classifier[1].in_features
model_ft_2.classifier[1] = nn.Linear(num_ftrs_2, 6)

model_ft_2 = model_ft_2.to(device)

criterion_2 = nn.CrossEntropyLoss()

# Only optimize the classifier parameters (unfrozen layer)
optimizer_ft_2 = optim.SGD(model_ft_2.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler_2 = lr_scheduler.StepLR(optimizer_ft_2, step_size=7, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 83.6MB/s]

# %% [markdown]
# ## Train and Evaluate the EfficientNet finetuning

# %%
model_ft_2 = train_model(model_ft_2, criterion_2, optimizer_ft_2, exp_lr_scheduler_2,
                       num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.9462 Acc: 0.6570
# val Loss: 0.4552 Acc: 0.8510
#
# Epoch 1/24
# ----------
# train Loss: 0.8143 Acc: 0.7039
# val Loss: 0.4702 Acc: 0.8367
#
# Epoch 2/24
# ----------
# train Loss: 0.8183 Acc: 0.7012
# val Loss: 0.4150 Acc: 0.8550
#
# Epoch 3/24
# ----------
# train Loss: 0.7888 Acc: 0.7135
# val Loss: 0.4664 Acc: 0.8303
#
# Epoch 4/24
# ----------
# train Loss: 0.8005 Acc: 0.7088
# val Loss: 0.4252 Acc: 0.8573
#
# Epoch 5/24
# ----------
# train Loss: 0.7933 Acc: 0.7139
# val Loss: 0.3880 Acc: 0.8667
#
# Epoch 6/24
# ----------
# train Loss: 0.7731 Acc: 0.7185
# val Loss: 0.4012 Acc: 0.8590
#
# Epoch 7/24
# ----------
# train Loss: 0.7798 Acc: 0.7143
# val Loss: 0.3937 Acc: 0.8660
#
# Epoch 8/24
# ----------
# train Loss: 0.7661 Acc: 0.7184
# val Loss: 0.4471 Acc: 0.8370
#
# Epoch 9/24
# ----------
# train Loss: 0.7730 Acc: 0.7205
# val Loss: 0.4102 Acc: 0.8577
#
# Epoch 10/24
# ----------
# train Loss: 0.7632 Acc: 0.7195
# ...

# %%
visualize_model(model_ft_2)

# %% [markdown]
# ## Inference on custom images

# %%
def visualize_model_predictions(model,img_path):
    was_training = model.training
    model.eval()

    img = Image.open(img_path)
    img = data_transforms['val'](img)
    img = img.unsqueeze(0)
    img = img.to(device)

    with torch.no_grad():
        outputs = model(img)
        _, preds = torch.max(outputs, 1)

        ax = plt.subplot(2,2,1)
        ax.axis('off')
        ax.set_title(f'Predicted: {class_names[preds[0]]}')
        imshow(img.cpu().data[0])

        model.train(mode=was_training)

# %% [markdown]
# ### For the first model "ResNet"

# %%
visualize_model_predictions(
    model_ft,
    img_path='./val/forest/20062.jpg'
)

plt.ioff()
plt.show()

# %% [markdown]
# ### For the scound model "EfficientNet"

# %%
visualize_model_predictions(
    model_ft_2,
    img_path='./val/glacier/20087.jpg'
)

plt.ioff()
plt.show()

# %% [markdown]
# # conclusion
# The ResNet model is the superior choice for your image classification project, as it definitively outperformed EfficientNet across the two most crucial evaluation criteria. ResNet achieved a notably higher Best Validation Accuracy (89.93%) compared to EfficientNet's 87.63%. Furthermore, ResNet demonstrated significant efficiency by completing its training cycle in just 23 minutes and 47 seconds, which is nearly 13 minutes faster than EfficientNet's 36 minutes and 34 seconds. This combination of higher accuracy and reduced training time makes ResNet the most efficient and effective solution for classifying your scenic and architectural images, confirming that its robust, time-tested architecture was better suited to quickly generalize the necessary features from your dataset than the more complex scaling methodology of EfficientNet.
